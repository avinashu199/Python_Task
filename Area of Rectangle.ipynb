# %%
#Calculate the area of rectangle while taking the user input Area= width * lenght
width=float(input("Enter the width of the rectangle:"))
length=float(input("Enter the length of the rectangle:"))
Area= width * length
print(f"Area of the rectangle is {Area} cm²")
# Out:
# Enter the width of the rectangle: 5.6
# Enter the length of the rectangle: 4.2
# Area of the rectangle is 23.52 cm²
