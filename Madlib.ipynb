# %%
holiday=input("Enter the holday name:")
friend=input("Enter the friends name:")
action=input("Enter the action details:")
item=input("Enter the item details:")
print(f"Today we celebrate {holiday} at {friend}'s house. When I {action} in the door. I could smell {item} cooking.")
# Out:
# Enter the holday name: Black friday
# Enter the friends name: Eshwar
