# %%
number1=float(input("Enter a number:"))
operator=input("Enter the operator[+ - * /]:")
number2=float(input("Enter a number"))
if operator=='+':
    sum=number1+number2
    print(f"The addition of numbers is: {sum}")
elif operator=='-':
    sub=number1-number2
    print(f"The subtraction of numbers is: {sub}")
el
