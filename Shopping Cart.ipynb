# %%
'''
Shopping cart program - item name, price and number of peices
'''
item=input("Enter the item name:")
quantity=int(input("Enter the number of quantity:"))
price=float(input("Enter the price of item:"))
Value= quantity * price
print(f"You have ordered {quantity} {}")
# Out:
# Enter the item name: pizza
# Enter the number of quantity: 1
# Enter the price of item: 1
