# %%
#kg=pound*0.453592
#pound=kg/0.453592
weight=float(input("Enter the weight of the person:"))
unit=input("Enter the unit of measurement[kg,lb]:")
if unit=='kg':
    result=weight/0.453592
    print(f"Weight is now converted to Pound: {round(result,2)} lb")
elif unit=='lb':
    result=weight*0.453592
    print(f"Weight is now converetd to KG: {round(result,2)} kg")
else:
    print("Enter the valid unit of weight as prompted")
# Out:
# Enter the weight of the person: 72
# Enter the unit of measurement[kg,lb]: kg
# Weight is now converted to Pound: 158.73 lb

# %%
#f=(c*9/5)+32
#c=(f-32)*5/9
temp=float(input("Enter the temperature"))
unit=input("Enter the unit of measurement[f,c]:")
if unit=='f':
    c=(temp-32)*5/9
    print(f"Converted to celius:{round(c,2)}")
elif unit=='c':
    f=
