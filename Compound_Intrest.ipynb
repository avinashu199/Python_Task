# %%
#Compound intrest calculator program using while loops and if loops
p=float(input("Enter the principle amount:"))
r=float(input("Enter the rate of intrest:"))
t=int(input("Enter the time period:"))
while p<=0:
    p=float(input("Principle amount should be greater than 0, please re-enter:"))
while r<=0:
    r=float(input("rate of intrest should be greater than 0, please re-enter:"))
while t<=0:
    t=float(input("Time period should be greater than 0, please re-enter:"))
print(f"The invested principle amount is: ${p}")
print(f"Rate of intrest applicable is: {r}%")
print(f"Time period in years that is with bank is: {t}yr")
result=p*pow(1+r/100)
# Out:
# Enter the principle amount: 1000
# Enter the rate of intrest: 14
# Enter the time period: 4
# The invested principle amount is: $1000.0
# Rate of intrest applicable is: 14.0%
# Time period in years that is with bank is: 4yr
