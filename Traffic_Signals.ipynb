# %%
import time
import datetime
directions=['Gandhinagar','Singhnagar','Elur Road','Bandar Road']
def yellow(road):
    print(f"{road}:Please wait for signal to change")
    counter=0
    while counter<3:
        c_dt=datetime.datetime.now()
        c_dt=c_dt.strftime("%H:%M:%S")
        print(c_dt)
        time.sleep(1)
        counter+=1  
def stop(road):
    print(f"{road}:Red Signal- Please Stop")

def start(road):
    print(f"{road}:Green Signal- Please move")
    counter=0 
    while counter<5:
        c_dt=datetime.datetime.now()
        c_dt=c_dt.strftime("%H:%M:%S")
        print(c_dt)
        time.sleep(1)
        counter+=1
    yellow(road)
for direction in directions:
    start(direction)
    stop(direction)
# Out:
# Gandhinagar:Green Signal- Please move
# 12:34:34
# 12:34:35
# 12:34:36
# 12:34:37
# 12:34:38
# Gandhinagar:Please wait for signal to change
# 12:34:39
# 12:34:40
# 12:34:41
# Gandhinagar:Red Signal- Please Stop
# Singhnagar:Green Signal- Please move
# 12:34:42
# 12:34:43
# 12:34:44
# 12:34:45
# 12:34:46
# Singhnagar:Please wait for signal to change
# 12:34:47
# 12:34:48
# 12:34:49
# Singhnagar:Red Signal- Please Stop
# Elur Road:Green Signal- Please move
# 12:34:50
# 12:34:51
# 12:34:52
# 12:34:53
# 12:34:54
