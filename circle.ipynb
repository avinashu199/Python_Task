# %%
#c=2*pi*r
import math
r=float(input("Enter the radious of the circle:"))
c=2*math.pi*r
print(f"Circumference of the circle is:{round(c,2)} cm")
# Out:
# Enter the radious of the circle: 5.6
# Circumference of the circle is:35.19 cm

# %%
#Area=pi*r2
import math
radius=float(input("Enter the radius of the circle:"))
Area=math.pi*math.pow(radius,2)
print(f"Area of circle is {round(Area,2)}")
# Out:
# Enter the radius of the circle: 4
# Area of circle is 50.27

# %%
#Hypotenuse of right angle triangle
import math
side1=float(input("Enter the length of side1:"))
side2=float(input("Enter the length of side2:"))
hyp=math.pow(side1,2)+math.p
